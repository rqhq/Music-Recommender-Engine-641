# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
from scipy import sparse

# %% [markdown]
# ## Load in all data files

# %%
artists = pd.read_csv('data/artists.dat', sep = '\t')
user_artists = pd.read_csv('data/user_artists.dat', sep = '\t')
#tags.dat has non-ascii chars so add latin-1
tags = pd.read_csv('data/tags.dat', sep='\t', encoding='latin-1')
user_tags = pd.read_csv('data/user_taggedartists.dat',sep='\t')
user_friends = pd.read_csv('data/user_friends.dat', sep = '\t')

# %%
print(f"Artists: {len(artists)}")
print(f"Tags: {len(tags)}")
print(f"Users: {user_artists['userID'].nunique()}")
print(f"Interactions: {len(user_artists)}")
print(f"Tag events: {len(user_tags)}")
print(f"Friendships: {len(user_friends)}")
# Out:
# Artists: 17632
# Tags: 11946
# Users: 1892
# Interactions: 92834
# Tag events: 186479
# Friendships: 25434
